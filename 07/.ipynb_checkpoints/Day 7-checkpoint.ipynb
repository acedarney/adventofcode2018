# %%
import networkx as nx
nx.__version__
# Out:
# '2.1'

# %%
G = nx.DiGraph()
G.add_edges_from([('C', 'A'),
                  ('C', 'F'),
                  ('A', 'B'),
                  ('A', 'D'),
                  ('B', 'E'),
                  ('D', 'E'),
                  ('F', 'E'),])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

nx.draw(G, with_labels=True)

# %%
list(nx.topological_sort(G))
# Out:
# ['C', 'F', 'A', 'B', 'D', 'E']

# %%
list(nx.lexicographical_topological_sort(G))
# Out:
# ['C', 'A', 'B', 'D', 'F', 'E']

# %%
G = nx.DiGraph()

with open('input.txt', 'r') as f:
    for line in f:
        G.add_edge(line[5], line[36])
        
nx.draw(G, with_labels=True)

# %%
sequence = ''.join(list(nx.lexicographical_topological_sort(G)))
sequence
# Out:
# 'ABLCFNSXZPRHVEGUYKDIMQTWJO'

# %% [markdown]
# # Part 2

# %%
import pandas as pd

index = [x for x in range(1, 1911)]
columns = [1, 2, 3, 4, 5]
times = [x+60 for x in range(1,27)]
time_dict = dict(zip(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), times))

sequence = list('ABLCFNSXZPRHVEGUYKDIMQTWJO')

df = pd.DataFrame(index=index, columns=columns)

for ix in index:
    for worker in columns:
        if pd.isnull(df.loc[ix, worker]):
#             print('Idle worker, add task')
            if sequence: # TODO: I have to check to ensure that all precursor activities are complete!
                new_task = sequence.pop(0)
                df.loc[ix:ix+time_dict[new_task], worker] = new_task
            else:
                break
        else:
            continue

df[1:450]
        
# 437 is too low
# Out:
#        1    2    3    4    5
# 2      A    B    L    C    F
# 3      A    B    L    C    F
# 4      A    B    L    C    F
# 5      A    B    L    C    F
# 6      A    B    L    C    F
# 7      A    B    L    C    F
# 8      A    B    L    C    F
# 9      A    B    L    C    F
# 10     A    B    L    C    F
# 11     A    B    L    C    F
# 12     A    B    L    C    F
# 13     A    B    L    C    F
# 14     A    B    L    C    F
# 15     A    B    L    C    F
# 16     A    B    L    C    F
# 17     A    B    L    C    F
# 18     A    B    L    C    F
# 19     A    B    L    C    F
# 20     A    B    L    C    F
# 21     A    B    L    C    F
# 22     A    B    L    C    F
# 23     A    B    L    C    F
# 24     A    B    L    C    F
# 25     A    B    L    C    F
# 26     A    B    L    C    F
# 27     A    B    L    C    F
# 28     A    B    L    C    F
# 29     A    B    L    C    F
# 30     A    B    L    C    F
# 31     A    B    L    C    F
# ..   ...  ...  ...  ...  ...
# 421  NaN  NaN  NaN  NaN    O
# 422  NaN  NaN  NaN  NaN    O
# 423  NaN  NaN  NaN  NaN    O
# 424  NaN  NaN  NaN  NaN    O
# 425  NaN  NaN  NaN  NaN    O
# 426  NaN  NaN  NaN  NaN    O
# 427  NaN  NaN  NaN  NaN    O
# 428  NaN  NaN  NaN  NaN    O
# 429  NaN  NaN  NaN  NaN    O
# 430  NaN  NaN  NaN  NaN    O
# 431  NaN  NaN  NaN  NaN    O
# 432  NaN  NaN  NaN  NaN    O
# 433  NaN  NaN  NaN  NaN    O
# 434  NaN  NaN  NaN  NaN    O
# 435  NaN  NaN  NaN  NaN    O
# 436  NaN  NaN  NaN  NaN    O
# 437  NaN  NaN  NaN  NaN    O
# 438  NaN  NaN  NaN  NaN  NaN
# 439  NaN  NaN  NaN  NaN  NaN
# 440  NaN  NaN  NaN  NaN  NaN
# 441  NaN  NaN  NaN  NaN  NaN
# 442  NaN  NaN  NaN  NaN  NaN
# 443  NaN  NaN  NaN  NaN  NaN
# 444  NaN  NaN  NaN  NaN  NaN
# 445  NaN  NaN  NaN  NaN  NaN
# 446  NaN  NaN  NaN  NaN  NaN
# 447  NaN  NaN  NaN  NaN  NaN
# 448  NaN  NaN  NaN  NaN  NaN
# 449  NaN  NaN  NaN  NaN  NaN
# 450  NaN  NaN  NaN  NaN  NaN
#
# [449 rows x 5 columns]

# %%
val = 0

for k, v in time_dict.items():
    val += v

val
# Out:
# 1911

# %%
import pandas as pd

index = [x for x in range(1, 20)]
columns = [1, 2]
times = [x for x in range(1,7)]
time_dict = dict(zip(list('ABCDEF'), times))
# print(time_dict)
sequence = list('CABFDE')

df = pd.DataFrame(index=index, columns=columns)

for ix in index:
    for worker in columns:
        if pd.isnull(df.loc[ix, worker]):
#             print('Idle worker, add task')
            if sequence: # TODO: I have to check to ensure that all precursor activities are complete!
                new_task = sequence.pop(0)
                df.loc[ix:ix+time_dict[new_task], worker] = new_task
            else:
                break
        else:
            continue

df
# Out:
#       1    2
# 1     C    A
# 2     C    A
# 3     C    B
# 4     C    B
# 5     F    B
# 6     F    D
# 7     F    D
# 8     F    D
# 9     F    D
# 10    F    D
# 11    F    E
# 12  NaN    E
# 13  NaN    E
# 14  NaN    E
# 15  NaN    E
# 16  NaN    E
# 17  NaN  NaN
# 18  NaN  NaN
# 19  NaN  NaN
